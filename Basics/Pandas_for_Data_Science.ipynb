# %% [markdown]
# <a href="https://colab.research.google.com/github/dipit099/Deep_Learning-Colab/blob/main/Pandas_for_Data_Science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 1. Create

# %% [markdown]
# ### 1.1 Create from a CSV

# %%
path= '/content/drive/MyDrive/Colab Notebooks/datasets/telco_churn.csv';
df = pd.read_csv(path)

# %% [markdown]
# ### 1.2 Create from a Dictionary

# %%
tempdict = {'col1':[1,2,3], 'col2':[4,5,6], 'col3':[7,8,9]}

# %%
dictdf = pd.DataFrame.from_dict(tempdict)
dictdf.head()
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6     9

# %% [markdown]
# # 2. Read

# %%
df.shape  #rows, columns
# Out:
# (3333, 20)

# %% [markdown]
# ### 2.1 Show Top 5 and Bottom 5 Rows

# %%
df.head(6)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
# 5    AL             118        510                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
# 5                      0              223.4             98.0
#
# ...

# %%
df.tail(6)
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3327    SC              79        415                 No              No
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3327                      0              134.7             98.0
# 3328                     36              156.2             77.0
# 3329                      0              231.1             57.0
# 3330                      0              180.8            109.0
# 3331                      0              213.8            105.0
# 3332                     25              234.4            113.0
#
# ...

# %% [markdown]
# ### 2.2 Show Columns and Data Type

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
df.dtypes
# Out:
# State                      object
# Account length              int64
# Area code                   int64
# International plan         object
# Voice mail plan            object
# Number vmail messages       int64
# Total day minutes         float64
# Total day calls           float64
# Total day charge          float64
# Total eve minutes         float64
# Total eve calls           float64
# Total eve charge          float64
# Total night minutes       float64
# Total night calls         float64
# Total night charge        float64
# Total intl minutes        float64
# Total intl calls            int64
# Total intl charge         float64
# Customer service calls    float64
# Churn                      object
# dtype: object

# %% [markdown]
# ### 2.3 Summary Statistics

# %%
df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3323.000000
# mean       101.064806   437.182418               8.099010         179.787150
# std         39.822106    42.371290              13.688365          54.419625
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.500000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3323.000000       3315.000000        3324.000000      3325.000000
# mean        100.456214         30.557831         201.033935       100.110677
# ...

# %% [markdown]
# 2.3.1 Print the Columns which have 'object' type data

# %%
df.describe(include='object')
# Out:
#        State International plan Voice mail plan  Churn
# count   3333               3333            3333   3325
# unique    51                  2               2      2
# top       WV                 No              No  False
# freq     106               3010            2411   2842

# %% [markdown]
# ### 2.4 Filtering Columns

# %%
df.State  # State is the name of the coln
# Out:
# 0       KS
# 1       OH
# 2       NJ
# 3       OH
# 4       OK
#         ..
# 3328    AZ
# 3329    WV
# 3330    RI
# 3331    CT
# 3332    TN
# Name: State, Length: 3333, dtype: object

# %%
df['International plan']
# Out:
# 0        No
# 1        No
# 2        No
# 3       Yes
# 4       Yes
#        ...
# 3328     No
# 3329     No
# 3330     No
# 3331    Yes
# 3332     No
# Name: International plan, Length: 3333, dtype: object

# %%
df[['State', 'International plan']]
# Out:
#      State International plan
# 0       KS                 No
# 1       OH                 No
# 2       NJ                 No
# 3       OH                Yes
# 4       OK                Yes
# ...    ...                ...
# 3328    AZ                 No
# 3329    WV                 No
# 3330    RI                 No
# 3331    CT                Yes
# 3332    TN                 No
#
# [3333 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_0.groupby('International plan').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df.Churn.unique()
# Out:
# array([False, nan, True], dtype=object)

# %% [markdown]
# ### 2.5 Filtering on Rows

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4             99.0             16.78
# ...

# %%
df[df['International plan']=='No']   ## condition checking
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 6       MA             121        510                 No             Yes
# 8       LA             117        408                 No              No
# ...    ...             ...        ...                ...             ...
# 3327    SC              79        415                 No              No
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df[(df['International plan']=='No') & (df['Churn']==True)]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 10      IN              65        415                 No              No
# 15      NY             161        415                 No              No
# 21      CO              77        408                 No              No
# 33      AZ              12        408                 No              No
# 48      ID             119        415                 No              No
# ...    ...             ...        ...                ...             ...
# 3280    AR              76        408                 No              No
# 3287    KS             170        415                 No             Yes
# 3301    CA              84        415                 No              No
# 3322    MD              62        408                 No              No
# 3323    IN             117        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %% [markdown]
# ### 2.6 Indexing with iloc

# %%
df.iloc[14]  #print the details of 15th row..indexing starts with zero
# Out:
# State                        IA
# Account length               62
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes           NaN
# Total day calls             NaN
# Total day charge            NaN
# Total eve minutes         307.2
# Total eve calls            76.0
# Total eve charge          26.11
# Total night minutes       203.0
# Total night calls          99.0
# Total night charge         9.14
# Total intl minutes         13.1
# Total intl calls              6
# Total intl charge          3.54
# Customer service calls      4.0
# Churn                     False
# Name: 14, dtype: object

# %%
df.iloc[14,-1]   ##print the details of 15th row and last coln [ -1 means last coln, -2 means 2nd last coln]
# Out:
# False

# %%
df.iloc[22:33]   # from 23th to 34rd row
# Out:
#    State  Account length  Area code International plan Voice mail plan  \
# 22    AZ             130        415                 No              No
# 23    SC             111        415                 No              No
# 24    VA             132        510                 No              No
# 25    NE             174        415                 No              No
# 26    WY              57        408                 No             Yes
# 27    MT              54        408                 No              No
# 28    MO              20        415                 No              No
# 29    HI              49        510                 No              No
# 30    IL             142        415                 No              No
# 31    NH              75        510                 No              No
# 32    LA             172        408                 No              No
#
#     Number vmail messages  Total day minutes  Total day calls  \
# ...

# %% [markdown]
# ### 2.7 Indexing with loc

# %%
state = df.copy()
state.set_index('State', inplace=True)
# previously , indexing was on row number...but what if we want indexing as "State" coln data-variables.
# inplace=true means dont create a coopy again

# %%
state.head()
# Out:
#        Account length  Area code International plan Voice mail plan  \
# State
# KS                128        415                 No             Yes
# OH                107        415                 No             Yes
# NJ                137        415                 No              No
# OH                 84        408                Yes              No
# OK                 75        415                Yes              No
#
#        Number vmail messages  Total day minutes  Total day calls  \
# State
# KS                        25              265.1            110.0
# OH                        26              161.6            123.0
# NJ                         0              243.4            114.0
# OH                         0              299.4             71.0
# OK                         0              166.7            113.0
#
#        Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# State
# ...

# %%
state.loc['OH']  #grab all those whose indexing coln has = 'OH'
# Out:
#        Account length  Area code International plan Voice mail plan  \
# State
# OH                107        415                 No             Yes
# OH                 84        408                Yes              No
# OH                 65        408                 No              No
# OH                 83        415                 No              No
# OH                 63        415                Yes             Yes
# ...               ...        ...                ...             ...
# OH                160        415                 No              No
# OH                 88        408                 No              No
# OH                106        415                 No             Yes
# OH                 78        408                 No              No
# OH                 96        415                 No              No
#
#        Number vmail messages  Total day minutes  Total day calls  \
# State
# OH                        26              161.6            123.0
# ...

# %% [markdown]
# # 3. Update

# %% [markdown]
# ### 3.1 Dropping Rows

# %%
df.isnull().sum()
# Out:
# State                      0
# Account length             0
# Area code                  0
# International plan         0
# Voice mail plan            0
# Number vmail messages      0
# Total day minutes         10
# Total day calls           10
# Total day charge          18
# Total eve minutes          9
# Total eve calls            8
# Total eve charge           0
# Total night minutes        0
# Total night calls          1
# Total night charge         0
# Total intl minutes         0
# Total intl calls           0
# Total intl charge          5
# Customer service calls     5
# Churn                      8
# dtype: int64

# %%
df.dropna(inplace=True)  #drop rows which have null values

# %%
df.isnull().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %% [markdown]
# ### 3.2 Dropping Columns

# %%
df.drop('Churn', axis=1)
#axis =1 means drop column
#NOTE: the drop method in pandas returns a new DataFrame with the specified rows or columns removed
# but does not modify the original DataFrame unless you explicitly update it or use the 'inplace' parameter.
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %% [markdown]
# ### 3.3 Creating Calculated Columns

# %%
df['New Column'] = df['Total night minutes'] + df['Total intl minutes']

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  ...  Total eve charge  \
# 0             45.07              197.4  ...             16.78
# ...

# %% [markdown]
# ### 3.4 Updating an Entire Column

# %%
df['New Column'] = 100

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  ...  Total eve charge  \
# 0             45.07              197.4  ...             16.78
# ...

# %% [markdown]
# ### 3.5 Updating a Single Value

# %%
df.iloc[0,-1] = 10    #0,-1 means 1st row and last coln r values

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  ...  Total eve charge  \
# 0             45.07              197.4  ...             16.78
# ...

# %% [markdown]
# # 4. Delete/Output

# %% [markdown]
# ### 4.1 Output to CSV

# %%
df.to_csv('output.csv')
